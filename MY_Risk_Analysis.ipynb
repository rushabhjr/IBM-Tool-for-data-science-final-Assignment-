# %% [markdown]
# <a href="https://colab.research.google.com/github/rushabhjr/IBM-Tool-for-data-science-final-Assignment-/blob/main/MY_Risk_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Risk Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy.stats import chi2
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Datasets

df = pd.read_csv("/content/drive/MyDrive/my_Analysis/loan.zip (Unzipped Files)/loan.csv")
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %% [markdown]
# Observation:
#
# Data has total 39717 Rows and 111 columns.
# There are columns having no values. So, better to drop those columns which has zero impact.

# %%
# Drop the columns having morethan 20% null values

df = df.drop(df.columns[df.apply(lambda col: col.isnull().sum()/len(df) > 0.20)], axis=1)
df.shape
# Out:
# (39717, 53)

# %%
df.isna().sum()
# Out:
# id                               0
# member_id                        0
# loan_amnt                        0
# funded_amnt                      0
# funded_amnt_inv                  0
# term                             0
# int_rate                         0
# installment                      0
# grade                            0
# sub_grade                        0
# emp_title                     2459
# emp_length                    1075
# home_ownership                   0
# annual_inc                       0
# verification_status              0
# issue_d                          0
# loan_status                      0
# pymnt_plan                       0
# url                              0
# purpose                          0
# title                           11
# zip_code                         0
# addr_state                       0
# dti                              0
# delinq_2yrs                      0
# earliest_cr_line                 0
# inq_last_6mths                   0
# open_acc                         0
# pub_rec                          0
# revol_bal                        0
# revol_util                      50
# total_acc                        0
# initial_list_status              0
# out_prncp                        0
# out_prncp_inv                    0
# total_pymnt                      0
# total_pymnt_inv                  0
# total_rec_prncp                  0
# total_rec_int                    0
# total_rec_late_fee               0
# recoveries                       0
# collection_recovery_fee          0
# last_pymnt_d                    71
# last_pymnt_amnt                  0
# last_credit_pull_d               2
# collections_12_mths_ex_med      56
# policy_code                      0
# application_type                 0
# acc_now_delinq                   0
# chargeoff_within_12_mths        56
# delinq_amnt                      0
# pub_rec_bankruptcies           697
# tax_liens                       39
# dtype: int64

# %%
# To check the unique values for each columns

df.nunique()
# Out:
# id                            39717
# member_id                     39717
# loan_amnt                       885
# funded_amnt                    1041
# funded_amnt_inv                8205
# term                              2
# int_rate                        371
# installment                   15383
# grade                             7
# sub_grade                        35
# emp_title                     28820
# emp_length                       11
# home_ownership                    5
# annual_inc                     5318
# verification_status               3
# issue_d                          55
# loan_status                       3
# pymnt_plan                        1
# url                           39717
# purpose                          14
# title                         19615
# zip_code                        823
# addr_state                       50
# dti                            2868
# delinq_2yrs                      11
# earliest_cr_line                526
# inq_last_6mths                    9
# open_acc                         40
# pub_rec                           5
# revol_bal                     21711
# revol_util                     1089
# total_acc                        82
# initial_list_status               1
# out_prncp                      1137
# out_prncp_inv                  1138
# total_pymnt                   37850
# total_pymnt_inv               37518
# total_rec_prncp                7976
# total_rec_int                 35148
# total_rec_late_fee             1356
# recoveries                     4040
# collection_recovery_fee        2616
# last_pymnt_d                    101
# last_pymnt_amnt               34930
# last_credit_pull_d              106
# collections_12_mths_ex_med        1
# policy_code                       1
# application_type                  1
# acc_now_delinq                    1
# chargeoff_within_12_mths          1
# delinq_amnt                       1
# pub_rec_bankruptcies              3
# tax_liens                         1
# dtype: int64

# %% [markdown]
# In the above observation there are columns having 39717 unique values which means every entry is unique and 1 which indicates that every value of the variable is same for every rows. So, these two columns are not impacting or not required for the further analysis. So, dropping them makes dataframe more usable and easy to understand.

# %%
# Drop the columns having unique values 1 and 39717

for col in df.columns:
    if df[col].nunique() == 1:
        df.drop(col,inplace=True,axis=1)

for col in df.columns:
    if len(df[col].unique()) == len(df):
        df.drop(col,inplace=True,axis=1)
print("After droping the columns, we have:")
print(" ")
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}")
# Out:
# After droping the columns, we have:
#
# Number of Rows: 39717
# Number of Columns: 41

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                39717 non-null  int64
#  1   funded_amnt              39717 non-null  int64
#  2   funded_amnt_inv          39717 non-null  float64
#  3   term                     39717 non-null  object
#  4   int_rate                 39717 non-null  object
#  5   installment              39717 non-null  float64
#  6   grade                    39717 non-null  object
#  7   sub_grade                39717 non-null  object
#  8   emp_title                37258 non-null  object
#  9   emp_length               38642 non-null  object
#  10  home_ownership           39717 non-null  object
#  11  annual_inc               39717 non-null  float64
#  12  verification_status      39717 non-null  object
#  13  issue_d                  39717 non-null  object
#  14  loan_status              39717 non-null  object
#  15  purpose                  39717 non-null  object
#  16  title                    39706 non-null  object
#  17  zip_code                 39717 non-null  object
#  18  addr_state               39717 non-null  object
#  19  dti                      39717 non-null  float64
#  20  delinq_2yrs              39717 non-null  int64
#  21  earliest_cr_line         39717 non-null  object
#  22  inq_last_6mths           39717 non-null  int64
#  23  open_acc                 39717 non-null  int64
#  24  pub_rec                  39717 non-null  int64
#  25  revol_bal                39717 non-null  int64
#  26  revol_util               39667 non-null  object
#  27  total_acc                39717 non-null  int64
#  28  out_prncp                39717 non-null  float64
#  29  out_prncp_inv            39717 non-null  float64
#  30  total_pymnt              39717 non-null  float64
#  31  total_pymnt_inv          39717 non-null  float64
#  32  total_rec_prncp          39717 non-null  float64
#  33  total_rec_int            39717 non-null  float64
#  34  total_rec_late_fee       39717 non-null  float64
#  35  recoveries               39717 non-null  float64
#  36  collection_recovery_fee  39717 non-null  float64
#  37  last_pymnt_d             39646 non-null  object
#  38  last_pymnt_amnt          39717 non-null  float64
#  39  last_credit_pull_d       39715 non-null  object
#  40  pub_rec_bankruptcies     39020 non-null  float64
# dtypes: float64(15), int64(8), object(18)
# memory usage: 12.4+ MB

# %%
df.describe(exclude='object').T
# Out:
#                            count          mean           std      min  \
# loan_amnt                39717.0  11219.443815   7456.670694   500.00
# funded_amnt              39717.0  10947.713196   7187.238670   500.00
# funded_amnt_inv          39717.0  10397.448868   7128.450439     0.00
# installment              39717.0    324.561922    208.874874    15.69
# annual_inc               39717.0  68968.926377  63793.765790  4000.00
# dti                      39717.0     13.315130      6.678594     0.00
# delinq_2yrs              39717.0      0.146512      0.491812     0.00
# inq_last_6mths           39717.0      0.869200      1.070219     0.00
# open_acc                 39717.0      9.294408      4.400282     2.00
# pub_rec                  39717.0      0.055065      0.237200     0.00
# revol_bal                39717.0  13382.528086  15885.016641     0.00
# total_acc                39717.0     22.088828     11.401709     2.00
# out_prncp                39717.0     51.227887    375.172839     0.00
# out_prncp_inv            39717.0     50.989768    373.824457     0.00
# total_pymnt              39717.0  12153.596544   9042.040766     0.00
# total_pymnt_inv          39717.0  11567.149118   8942.672613     0.00
# total_rec_prncp          39717.0   9793.348813   7065.522127     0.00
# total_rec_int            39717.0   2263.663172   2608.111964     0.00
# total_rec_late_fee       39717.0      1.363015      7.289979     0.00
# recoveries               39717.0     95.221624    688.744771     0.00
# collection_recovery_fee  39717.0     12.406112    148.671593     0.00
# last_pymnt_amnt          39717.0   2678.826162   4447.136012     0.00
# pub_rec_bankruptcies     39020.0      0.043260      0.204324     0.00
#
#                               25%           50%          75%           max
# loan_amnt                 5500.00  10000.000000  15000.00000  3.500000e+04
# funded_amnt               5400.00   9600.000000  15000.00000  3.500000e+04
# funded_amnt_inv           5000.00   8975.000000  14400.00000  3.500000e+04
# installment                167.02    280.220000    430.78000  1.305190e+03
# annual_inc               40404.00  59000.000000  82300.00000  6.000000e+06
# dti                          8.17     13.400000     18.60000  2.999000e+01
# delinq_2yrs                  0.00      0.000000      0.00000  1.100000e+01
# inq_last_6mths               0.00      1.000000      1.00000  8.000000e+00
# open_acc                     6.00      9.000000     12.00000  4.400000e+01
# pub_rec                      0.00      0.000000      0.00000  4.000000e+00
# revol_bal                 3703.00   8850.000000  17058.00000  1.495880e+05
# total_acc                   13.00     20.000000     29.00000  9.000000e+01
# out_prncp                    0.00      0.000000      0.00000  6.311470e+03
# out_prncp_inv                0.00      0.000000      0.00000  6.307370e+03
# total_pymnt               5576.93   9899.640319  16534.43304  5.856368e+04
# total_pymnt_inv           5112.31   9287.150000  15798.81000  5.856368e+04
# total_rec_prncp           4600.00   8000.000000  13653.26000  3.500002e+04
# total_rec_int              662.18   1348.910000   2833.40000  2.356368e+04
# total_rec_late_fee           0.00      0.000000      0.00000  1.802000e+02
# recoveries                   0.00      0.000000      0.00000  2.962335e+04
# collection_recovery_fee      0.00      0.000000      0.00000  7.002190e+03
# last_pymnt_amnt            218.68    546.140000   3293.16000  3.611520e+04
# pub_rec_bankruptcies         0.00      0.000000      0.00000  2.000000e+00

# %% [markdown]
# Observations:
#
# Minimum amount of loan given is 500 and maximum is 35000
# Highest annual income provided by the borrower is 6000000 and lowest income is 4000.
# Maximum interest received 23563.68 and least interest is 0.

# %%
df.describe(include='object').T
# Out:
#                      count unique                 top   freq
# term                 39717      2           36 months  29096
# int_rate             39717    371              10.99%    956
# grade                39717      7                   B  12020
# sub_grade            39717     35                  B3   2917
# emp_title            37258  28820             US Army    134
# emp_length           38642     11           10+ years   8879
# home_ownership       39717      5                RENT  18899
# verification_status  39717      3        Not Verified  16921
# issue_d              39717     55              Dec-11   2260
# loan_status          39717      3          Fully Paid  32950
# purpose              39717     14  debt_consolidation  18641
# title                39706  19615  Debt Consolidation   2184
# zip_code             39717    823               100xx    597
# addr_state           39717     50                  CA   7099
# earliest_cr_line     39717    526              Nov-98    370
# revol_util           39667   1089                  0%    977
# last_pymnt_d         39646    101              May-16   1256
# last_credit_pull_d   39715    106              May-16  10308

# %%
plt.figure(figsize=(25,8))
sns.distplot(df.funded_amnt_inv, kde=True)
plt.show()

# %%
sns.factorplot("loan_status", col='purpose', col_wrap=3, data=df, kind='count');

# %%
plt.figure(figsize=(25,10))
sns.countplot(x=df.home_ownership, hue=df.loan_status)
plt.xticks(rotation=90);
